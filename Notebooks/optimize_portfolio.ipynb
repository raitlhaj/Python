# %% [markdown]
# IN PROGRESS ...

# %%
import sys
from underlyings.basket import Basket
from underlyings.stock import Stock
from underlyings.index import Index
from underlyings.optimize_portfolio import optimize_portfolio
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Tickers not found to check :  WCN - TTE - SGML- GH -TT
basket = Basket(["SPX","NASDAQ","AAPL","AMZN", "AVGO","MSFT","MDT","NVDA","AMD","IBM","LEN","ITW","AOS","XOM"], [ 1 / 14] * 14)
Ndxbasket = Basket(["SPX","AAPL","AMZN", "AVGO","MSFT","MDT","NVDA","AMD","SPLK","TTWO","FANG","CCEP","CDW",
                    "ANSS","ZS","VRSK","BKR","CSGP","ON","EA","DASH","FAST","TEAM","CTSH", "AZN","PAYX",
                    ##"KHC","ODFL","FTNT","IDXX","KDP","ROST","CPRT","DXCM","MCHP","PCAR","ADSK","MRVL","WDAY","CHTR","ROP","CRWD","ABNB","MNST",
                    "NXPI","CTAS","LULU","MAR","ASML","CSX","CDNS","SNPS","KLAC","MELI","REGN","PANW","MU","MDLZ","ADI",
                    "LRCX","VRTX","ISRG","BKNG","AMAT","AMGN","QCOM","INTU","CMCSA","TMUS","CSCO","ADBE","COST",
                    "GOOG","GOOGL","TSLA","NFLX","INTC"
                    #HighRisk+LowReturn# "WBA","PYPL","ILMN","DLTR","SIRI","PDD","MDB","PEP","HON","GILD","SBUX","ADP","TXN","EXC","AEP","XEL"
                    #HighRisk "DDOG","TTD",
                    #"META", "BIIB","PRLY","MRNA","GEHC","CEG","GSF","WBD"
                    ], [ 1 / 14] * 14)

start_date = pd.to_datetime('2023-01-02')
end_date = pd.datetime.today().strftime('%Y-%m-%d')

optimize_portfolio(Ndxbasket, start_date, end_date, x_min = 0.00001, x_max = 0.2, vol_max = 0.03, islog = False)
# Out:
# Vector_returns:
# [ 0.25085641  0.54777325  0.78722908  1.02791429  0.56640788  0.0571173
#   2.45944813  1.32364886  0.75143976  0.56599748  0.18229563  0.22921266
#   0.27402373  0.51634261  1.03684545  0.33985564  0.18956522  0.13341919
#   0.37932154  0.11368078  1.07216708  0.36793249  0.90687747  0.31689529
#  -0.02928025  0.03186253  0.49029345  0.33876033  0.57467994  0.51661591
#   0.37898721  0.125       0.7116011   0.61852477  0.55695127  0.91451502
#   0.22378447  1.13492235  0.7073655   0.09071698  0.23262542  0.90603427
#   0.43091392  0.27391484  0.74709799  0.68634343  0.10246513  0.36063433
#   0.60545018  0.2403711   0.1431962   0.0529829   0.76754126  0.46289269
#   0.57502787  0.57349641  1.34209066  0.66302763  0.88514777]
#
# Vols:
# [0.00825503 0.0125568  0.0207908  0.02032564 0.01583192 0.0136135
#  0.03052385 0.02955786 0.02383662 0.01806146 0.01830078 0.01087331
#  0.01523009 0.02070886 0.03217598 0.01256875 0.01710103 0.01718079
# ...
