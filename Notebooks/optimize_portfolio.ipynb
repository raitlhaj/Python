# %% [markdown]
# IN PROGRESS ...

# %%
import sys
from underlyings.basket import Basket
from underlyings.stock import Stock
from underlyings.index import Index
from underlyings.optimize_portfolio import optimize_portfolio
import pandas as pd
import matplotlib.pyplot as plt

# Tickers not found to check : GH - WCN - TTE - SGML
basket = Basket(["SPX","AAPL","TSLA","AMZN", "AVGO","BA","MDT", "ITW", "ADP","NDAQ","BBY","AOS","XOM","YPF","EMR"], [ 1 / 15] * 15)

basket_price_date = pd.to_datetime('2020-01-01')
start_date = pd.to_datetime('2023-01-01')
end_date = pd.to_datetime('2023-06-01')

optimize_portfolio(basket, start_date, end_date, x_min = 0.00001, x_max = 0.3, vol_max = 0.01, islog = False)
# Out:
# Vector_returns:
# [-0.08798667 -0.38619816 -0.58518127 -0.36539817 -0.21778167 -0.00908466
#  -0.10324812 -0.03269631  0.09464779  0.1026764   0.13924823 -0.12792615
#   0.00524246 -0.24110218  0.13550618]
#
# Vols:
# [0.00962585 0.01396638 0.03707675 0.02346064 0.01570426 0.01728677
#  0.01440636 0.0149556  0.01312494 0.01431942 0.01685391 0.02153687
#  0.01810857 0.03756388 0.01604744]
#
# Correls:
# [[ 1.          0.80446502  0.55036774  0.64940856  0.7282549   0.58559049
#    0.47213018  0.73326433  0.67060241  0.68963027  0.61950351  0.50704468
#    0.43302566  0.35943939  0.64685609]
#  [ 0.80446502  1.          0.49725749  0.53829937  0.62955914  0.36329927
#    0.36979249  0.5626185   0.5045875   0.60338674  0.47372373  0.33060953
#    0.2650802   0.17754599  0.5060963 ]
#  [ 0.55036774  0.49725749  1.          0.40136384  0.36427703  0.2433414
#    0.21840642  0.33724683  0.17557675  0.42191946  0.33246513  0.22678735
#    0.10476138  0.17556017  0.220362  ]
# ...
