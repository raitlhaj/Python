# %% [markdown]
# IN PROGRESS ...

# %%
import sys
from underlyings.basket import Basket
from underlyings.stock import Stock
from underlyings.index import Index
from underlyings.optimize_portfolio import optimize_portfolio
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np

# Tickers not found to check :  WCN - TTE - SGML- GH -TT
basket = Basket(["SPX","NASDAQ","AAPL","AMZN", "AVGO","MSFT","MDT","NVDA","AMD","IBM","LEN","ITW","AOS","XOM"], [ 1 / 14] * 14)
Ndxbasket = Basket(["SPX","AAPL","AMZN", "AVGO","MSFT","MDT","NVDA","AMD","TT","TTWO","FANG","CCEP","CDW",
                    "ANSS","ZS","VRSK","BKR","CSGP","ON","EA","DASH","FAST","TEAM","CTSH", "AZN","PAYX",
                    ##"KHC","ODFL","FTNT","IDXX","KDP","ROST","CPRT","DXCM","MCHP","PCAR","ADSK","MRVL","WDAY","CHTR","ROP","CRWD","ABNB","MNST",
                    "NXPI","CTAS","LULU","MAR","ASML","CSX","CDNS","SNPS","KLAC","MELI","REGN","PANW","MU","MDLZ","ADI",
                    "LRCX","VRTX","ISRG","BKNG","AMAT","AMGN","QCOM","INTU","CMCSA","TMUS","CSCO","ADBE","COST",
                    "GOOG","GOOGL","TSLA","NFLX","INTC"
                    #HighRisk+LowReturn# "WBA","PYPL","ILMN","DLTR","SIRI","PDD","MDB","PEP","HON","GILD","SBUX","ADP","TXN","EXC","AEP","XEL"
                    #HighRisk "DDOG","TTD",
                    #"META", "BIIB","PRLY","MRNA","GEHC","CEG","GSF","WBD"
                    ], [ 1 / 14] * 14)

start_date = "03/01/2023"
end_date = dt.datetime.today().strftime('%Y-%m-%d')

optimize_portfolio(Ndxbasket, start_date, end_date, x_min = 0.00001, x_max = 0.2, vol_max = 0.03, islog = False)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 26
#      23 start_date = "03/01/2023"
#      24 end_date = dt.datetime.today().strftime('%Y-%m-%d')
# ---> 26 optimize_portfolio(Ndxbasket, start_date, end_date, x_min = 0.00001, x_max = 0.2, vol_max = 0.03, islog = False)
#
# File ~\Documents\MEGA\IT QUANT\Python\underlyings\underlyings\optimize_portfolio.py:22, in optimize_portfolio(basket, start_date, end_date, x_min, x_max, vol_max, islog)
#      19 betas = np.zeros(shape = (1, nb_compo))
#      20 matrix_vols = np.zeros(shape = (1, nb_compo))
# ---> 22 idx_bench_quotes = Index(all_refs[0]).get_quotes(start_date, end_date)
#      23 len_idx = len(idx_bench_quotes)
#      25 matrix_returns = np.zeros(shape = (len_idx - 1, nb_compo ))
#
# File ~\Documents\MEGA\IT QUANT\Python\underlyings\underlyings\index.py:44, in Index.get_quotes(self, start_date, end_date)
#      41         chaine = str(chaine) + country + ": "+self.ticker+ "=> KO \n"
#      43 chaine = str(chaine) + country + ": "+ self.ticker + "=> OK \n"
# ---> 44 df = pd.DataFrame(resp_dict.get('data'))
#      45 df_new = pd.DataFrame(df['last_close'])
#      46 df_new.rename(columns = {'last_close': self.ticker} , inplace = True )
#
# UnboundLocalError: cannot access local variable 'resp_dict' where it is not associated with a value
