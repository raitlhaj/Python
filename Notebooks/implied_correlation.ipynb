# %% [markdown]
# IN PROGRESS ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
from underlyings.imply_correlation import imply_correl
from underlyings.basket import Basket
import pandas as pd

basket = Basket( ['AAPL','NKLA',"F","TSLA", "AVGO","BA","MDT", "ITW", "ADP","AMZN","NDAQ","BBY","AOS","XOM","YPF","EMR"], [1/16]*16)

start_date = "03/01/2023" #pd.to_datetime('2020-01-01')
end_date = "05/05/2023" #pd.to_datetime('2020-01-01')

imply = imply_correl( "AAPL", basket, start_date, end_date) 
basket.get_quotes(start_date, end_date)
# Out:
# Implied correlation : 0.04990186178575048
#         Basket
# 0   139.370625
# 1   135.927500
# 2   137.224375
# 3   137.641875
# 4   140.851875
# 5   140.580000
# 6   139.444375
# 7   136.770000
# 8   137.974375
# 9   140.281250
# 10  139.774375
# 11  139.505000
# 12  141.024375
# 13  141.020625
# 14  140.267500
# 15  139.097500
# 16  140.238750
# 17  138.464375
# 18  139.343125
# 19  139.380000
# 20  139.221250
# 21  139.552500
# 22  141.398750
# 23  143.301250
# 24  143.750000
# 25  141.276875
# 26  140.208125
# 27  138.165625
# 28  138.048125
# 29  138.174375
# 30  138.239375
# 31  137.825000
# 32  140.393750
# 33  138.768750
# 34  136.568750
# 35  138.045625
# 36  135.812500
# 37  137.784375
# 38  135.293125
# 39  135.174375
# 40  136.901250
# 41  139.475625
# 42  139.445625
# 43  141.648125
# 44  141.987500
# 45  137.765625
# 46  137.356875
