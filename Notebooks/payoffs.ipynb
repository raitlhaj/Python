# %% [markdown]
# [IN PROGRESS]
#
# We aim to present here the charts of servral payoffs and strategies
#
# Please feel free to suggest ;)
#
# Please note that PROFIT = PAYOFF +/- PREMIUM (capitalised)

# %%
import sys
from pricing.options  import Payoffs

ps = Payoffs("All")

ps.run()
