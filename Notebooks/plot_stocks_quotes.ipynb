# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from underlyings.stock import Stock
from underlyings.index import Index
from datetime import datetime

# %matplotlib inline
spx = Index("SPX")
apple = Stock('AAPL')
tsla = Stock("TSLA")

start_date =  pd.to_datetime('2018-01-01')
end_date = datetime.today().strftime('%Y-%m-%d')

df_apple = apple.get_quotes(start_date, end_date)
df_tsla = tsla.get_quotes(start_date, end_date)
df_spx = spx.get_quotes(start_date, end_date)

plt.plot(df_apple, label='AAPL')
plt.plot(df_tsla, label='TSLA')

# Setting the title and labels
plt.title('TSLA & AAPL Series')
plt.xlabel('X')
plt.ylabel('Price')

# Adding the legend
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 16
#      13 start_date =  pd.to_datetime('2018-01-01')
#      14 end_date = datetime.today().strftime('%Y-%m-%d')
# ---> 16 df_apple = apple.get_quotes(start_date, end_date)
#      17 df_tsla = tsla.get_quotes(start_date, end_date)
#      18 df_spx = spx.get_quotes(start_date, end_date)
#
# File ~\Documents\MEGA\IT QUANT\Python\underlyings\underlyings\stock.py:43, in Stock.get_quotes(self, start_date, end_date)
#      40         chaine = str(chaine) + country + ": "+self.ticker+ "=> KO \n"
#      42 chaine = str(chaine) + country + ": "+ self.ticker + "=> OK \n"
# ---> 43 df = pd.DataFrame(resp_dict.get('data'))
#      44 df_new = pd.DataFrame(df['last_close'])
#      45 df_new.rename(columns = {'last_close': self.ticker} , inplace = True )
#
# UnboundLocalError: cannot access local variable 'resp_dict' where it is not associated with a value
