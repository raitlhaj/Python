# %%
from openai import OpenAI

client = OpenAI()

client
#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
completion = client.chat.completions.create(
    model="gpt-4o",
    
    messages=[
        {
            "role": "user",
            "content": "Write a one-sentence bedtime story about a unicorn."
        }
    ]
)

print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 from openai import OpenAI
# ----> 3 client = OpenAI()
#       5 client
#       6 #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
#
# File c:\Users\Administrateur\AppData\Local\Programs\Python\Python311\Lib\site-packages\openai\_client.py:114, in OpenAI.__init__(self, api_key, organization, project, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     112     api_key = os.environ.get("OPENAI_API_KEY")
#     113 if api_key is None:
# --> 114     raise OpenAIError(
#     115         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     116     )
#     117 self.api_key = api_key
#     119 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
